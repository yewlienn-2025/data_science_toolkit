# %%
print("Welcome to data science")
# Out:
# Welcome to data science

# %%
x=5
print(x)
print("Value of x is:" , x)
print(type(x))
# Out:
# 5
# Value of x is: 5
# <class 'int'>

# %%
a = 4.7
print(a)
print(type(a))
# Out:
# 4.7
# <class 'float'>

# %%
#this is just a comment
print('hello')
# Out:
# hello

# %%
#A variable which stores an interger value
x = 13 #15.3014
x
print(f'helllooo{x}')
print(type(x)) #get data type
print(x)

#operations
y =12
z= x%y #can do lots of operations
print(f'z is :{z}')# f- f string
# Out:
# helllooo13
# <class 'int'>
# 13
# z is :1

# %%
#A variable which stores a string
x = 'abcde'
print(type(x)) #get the datatype
print(x)

x= "my name is shah"
print(f'the char {x[2]}') #indexing in python starts 0
print(f'The length of the string x is :{len(x)}') #prints the length of the string

y = ' and i am your teacher'

z = x+y
print(z)
# Out:
# <class 'str'>
# abcde
# the char
# The length of the string x is :15
# my name is shah and i am your teacher
